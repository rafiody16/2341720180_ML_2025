# %% [markdown]
# ###Praktikum 1 - Exact NN vs. ANNOY

# %% [markdown]
# ####Langkah 1 - Install library ANNOY

# %%
# !pip install annoy
# Out:
# Requirement already satisfied: annoy in /usr/local/lib/python3.12/dist-packages (1.17.3)

# %% [markdown]
# ####Langkah 2 - Import library

# %%
import numpy as np
import matplotlib.pyplot as plt
import time

from annoy import AnnoyIndex

# %% [markdown]
# ####Langkah 3 - Membuat dataset dummy

# %%
np.random.seed(42)
n_points = 1000
X = np.random.rand(n_points, 2) * 100

query = X[np.random.randint(0, n_points)]

# %% [markdown]
# ####Langkah 4 - Exact NN

# %%
start = time.time()
distances = np.linalg.norm(X - query, axis=1)
idx_exact = np.argsort(distances)[:3]
time_exact = time.time()

print("Exact NN index: ", idx_exact)
print("Exact NN jarak: ", distances[idx_exact])
print("Waktu Exact: ", round(time_exact * 1000, 4), "ms")
# Out:
# Exact NN index:  [219 898 593]
# Exact NN jarak:  [0.         1.36915938 2.27931544]
# Waktu Exact:  1759977433932.816 ms

# %% [markdown]
# ####Langkah 5 - Perhitungan jarak dengan ANNOY

# %%
# ANNOY 3 Tree
f = 2 # Dimensi
t = AnnoyIndex(f, 'euclidean')
for i, vec in enumerate(X):
  t.add_item(i, vec)

t.build(3) # 3 Trees

start = time.time()
idx_ann = t.get_nns_by_vector(query, 3) # find 3 NN
time_ann = time.time() - start

print("\nAnnoy NN index: ", idx_ann)
print("Annoy NN jarak: ", [np.linalg.norm(X[i] - query) for i in idx_ann])
print("Waktu Annoy: ", round(time_ann*1000, 4), "ms")
# Out:
# Annoy NN index:  [219, 898, 770]
# Annoy NN jarak:  [np.float64(0.0), np.float64(1.369159376273702), np.float64(2.568167959732514)]
# Waktu Annoy:  0.154 ms

# %% [markdown]
# ####Langkah 6 - Visualisasi Hasil NN

# %%
plt.figure(figsize=(6,6))
plt.scatter(X[:,0], X[:,1], c="lightgray", s=20, label="Dataset")
plt.scatter(query[0], query[1], c="red", marker="x", s=100, label="Query")

# Exact NN ditandai biru
plt.scatter(X[idx_exact,0], X[idx_exact,1], c="blue", s=80, label="Exact NN")

# Annoy NN ditandai hijau
plt.scatter(X[idx_ann,0], X[idx_ann,1], c="green", s=50, marker="s", label="Annoy NN")

plt.legend()
plt.title("Exact NN vs Annoy NN (3 trees)")
plt.show()

# %% [markdown]
# ###Praktikum 2 - Exact NN vs. FAISS

# %% [markdown]
# ####Langkah 1 - Install FAISS

# %%
# !pip install faiss-cpu
# !pip install faiss-gpu
# Out:
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.12.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.1 kB)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /usr/local/lib/python3.12/dist-packages (from faiss-cpu) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from faiss-cpu) (25.0)
# Downloading faiss_cpu-1.12.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (31.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.4/31.4 MB 39.3 MB/s eta 0:00:00
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.12.0
# ERROR: Could not find a version that satisfies the requirement faiss-gpu (from versions: none)
# ERROR: No matching distribution found for faiss-gpu

# %% [markdown]
# ####Langkah 2 - Import Library

# %%
import numpy as np
import faiss
import matplotlib.pyplot as plt
import time

# %% [markdown]
# ####Langkah 3 - Membuat dummy dataset

# %%
np.random.seed(42)
X = np.random.rand(1000, 2).astype('float32') # 1000 data 2D
query = np.array([[0.5, 0.5]], dtype='float32') # Query Point

# %% [markdown]
# ####Langkah 4 - Membuat model exact NN

# %%
# Search NN dengan Extract NN
index_flat = faiss.IndexFlatL2(2)
index_flat.add(X)

# Compute Extract NN Time
start = time.time()
D_flat, I_flat = index_flat.search(query, 3)
end = time.time()
time_flat = end -start

# %% [markdown]
# ####Langkah 5 - Buat Model FAISS

# %%
# Compute FAISS
nlist = 10
m = 2
quantizer = faiss.IndexFlatL2(2)
index_ivfpq = faiss.IndexIVFPQ(quantizer, 2, nlist, m, 8)

index_ivfpq.train(X) # Trainning centroid
index_ivfpq.add(X)

start = time.time()
D_ivfpq, I_ivfpq = index_ivfpq.search(query, 3)
end = time.time()
time_ivfpq = end - start

# %% [markdown]
# ####Langkah 6 - Cek hasil performa

# %%
# Print The Peformances
print("Exact NN (Flat) indices:", I_flat, "distances:", D_flat)
print("IVF+PQ indices:", I_ivfpq, "distances:", D_ivfpq)
print("Waktu Exact:", time_flat)
print("Waktu IVF+PQ:", time_ivfpq)
# Out:
# Exact NN (Flat) indices: [[137 170 750]] distances: [[0.00013095 0.00077404 0.00079751]]
# IVF+PQ indices: [[137 170 750]] distances: [[0.00012945 0.00079226 0.00080067]]
# Waktu Exact: 0.00019931793212890625
# Waktu IVF+PQ: 0.00018143653869628906

# %% [markdown]
# ####Langkah 7 - Visualisasi

# %%
# Visualize
plt.scatter(X[:,0], X[:,1], alpha=0.4, label="Dataset")
plt.scatter(query[:,0], query[:,1], c='red', marker='*', s=200, label="Query")

# Flat NN -> Exact NN
plt.scatter(X[I_flat[0],0], X[I_flat[0],1], c='blue', s=100, edgecolor='k', label="Exact NN")

# IVF+PQ NN -> FAISS
plt.scatter(X[I_ivfpq[0],0], X[I_ivfpq[0],1], c='green', marker='x', s=100, label="IVF+PQ NN")

plt.legend()
plt.title("Exact NN vs FAISS IVF+PQ")
plt.show()

# %% [markdown]
# ###Praktikum 3 - Exact NN vs. HNSW

# %% [markdown]
# ####Langkah 1 - Instal Library

# %%
# !pip install hnswlib
# Out:
# Collecting hnswlib
#   Downloading hnswlib-0.8.0.tar.gz (36 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from hnswlib) (2.0.2)
# Building wheels for collected packages: hnswlib
#   Building wheel for hnswlib (pyproject.toml) ... done
#   Created wheel for hnswlib: filename=hnswlib-0.8.0-cp312-cp312-linux_x86_64.whl size=2528148 sha256=34cf61c43ae9dd6a1bf7818f1def2ca7929341cde0671f516bf308c72477450e
#   Stored in directory: /root/.cache/pip/wheels/ac/39/b3/cbd7f9cbb76501d2d5fbc84956e70d0b94e788aac87bda465e
# Successfully built hnswlib
# Installing collected packages: hnswlib
# Successfully installed hnswlib-0.8.0

# %% [markdown]
# ####Langkah 2 - Import Library

# %%
import hnswlib
import numpy as np
import time
from sklearn.neighbors import NearestNeighbors

# %% [markdown]
# ####Langkah 3 - Membuat dataset dummy

# %%
num_elements = 1000
dim = 2
data = np.random.random((num_elements, dim)).astype(np.float32)

query = np.array([[0.5, 0.5]], dtype=np.float32)
k = 5 # Mencari Neighbors terderkat

# %% [markdown]
# ####Langkah 4 - Membuat Model NN

# %%
nn = NearestNeighbors(n_neighbors=k, algorithm='brute', metric='euclidean')
nn.fit(data)

start = time.time()
distances, indices = nn.kneighbors(query)
end = time.time()

print("=== Exact NN ===")
print("Indices:", indices)
print("Distances:", distances)
print("Waktu:", end - start, "s")
# Out:
# === Exact NN ===
# Indices: [[830 247 473 913 592]]
# Distances: [[0.00993625 0.01363944 0.01646171 0.03779694 0.03859071]]
# Waktu: 0.09215140342712402 s

# %% [markdown]
# ####Langkah 5 - Membuat model HNSW

# %%
p = hnswlib.Index(space='l2', dim=dim) # Mengganti '12' menjadi 'l2'

p.init_index(max_elements=num_elements, ef_construction=100, M=16)
p.add_items(data)
p.set_ef(50)

start = time.time()
labels, distances = p.knn_query(query, k=k)
end = time.time()

print("\n=== HNSW ===")
print("Indices:", labels)
print("Distances:", distances)
print("Waktu:", end - start, "s")
# Out:
# === HNSW ===
# Indices: [[830 247 473 913 592]]
# Distances: [[9.8728990e-05 1.8603441e-04 2.7098786e-04 1.4286089e-03 1.4892431e-03]]
# Waktu: 0.0002493858337402344 s

# %% [markdown]
# ###Praktikum 4 - ANNOY vs. FAISS vs. HNSW

# %% [markdown]
# ####Import Library

# %%
import numpy as np
import time
from annoy import AnnoyIndex
import faiss
import hnswlib

# %% [markdown]
# ####Membuat dataset

# %%
n_data = 1_000_000
dim = 5
X = np.random.random((n_data, dim)).astype(np.float32)

query = np.random.random((1, dim)).astype(np.float32)
k = 10

# %% [markdown]
# ####Annoy

# %%
ann_index = AnnoyIndex(dim, 'euclidean')

start = time.time()
for i in range(n_data):
  ann_index.add_item(i, X[i])
ann_index.build(10) # 10 Trees
build_time = time.time()

start = time.time()
neighbors = ann_index.get_nns_by_vector(query[0], k, include_distances=True)
query_time = time.time() - start

print("Build time:", build_time, "detik")
print("Query time:", query_time, "detik")
print("Neighbors:", neighbors[0][:5], "...")
# Out:
# Build time: 1759977550.546532 detik
# Query time: 0.0003414154052734375 detik
# Neighbors: [129179, 559276, 630783, 213191, 559393] ...

# %% [markdown]
# ####FAISS

# %%
faiss_index = faiss.IndexFlatL2(dim)

start = time.time()
faiss_index.add(X)
build_time = time.time() - start

start = time.time()
distances, indices = faiss_index.search(query, k)
query_time = time.time() - start


print("Build time:", build_time, "detik")
print("Query time:", query_time, "detik")
print("Neighbors:", indices[0][:5], "...")
# Out:
# Build time: 0.029767990112304688 detik
# Query time: 0.013480901718139648 detik
# Neighbors: [129179 559276 630783 213191 559393] ...

# %% [markdown]
# ####HNSW

# %%
hnsw_index = hnswlib.Index(space='l2', dim=dim)

start = time.time()
hnsw_index.init_index(max_elements=n_data, ef_construction=200, M=16)
hnsw_index.add_items(X)
build_time = time.time() - start

hnsw_index.set_ef(50)

start = time.time()
labels, distances = hnsw_index.knn_query(query, k=k)
query_time = time.time() - start

print("Build time:", build_time, "detik")
print("Query time:", query_time, "detik")
print("Neighbors:", labels[0][:5], "...")
# Out:
# Build time: 168.04857969284058 detik
# Query time: 0.00021982192993164062 detik
# Neighbors: [129179 559276 630783 213191 559393] ...

# %% [markdown]
# ###Praktikum 5 - Uji Performansi ANN dengan Recall Query

# %% [markdown]
# ####Import library

# %%
import numpy as np
import time
import faiss
from annoy import AnnoyIndex
import hnswlib
import matplotlib.pyplot as plt

# %% [markdown]
# ####Membuat dataset random

# %%
d = 128 # dimensi
nb = 100000 # jumlah database vector
nq = 1000 # jumlah query

np.random.seed(42)
xb = np.random.random((nb, d)).astype('float32')
xq = np.random.random((nq, d)).astype('float32')

# %% [markdown]
# ####Ground truth dengan FAISS brute force

# %%
index_flat = faiss.IndexFlatL2(d)
index_flat.add(xb)
k = 10
_, gt_idx = index_flat.search(xq, k)

# %% [markdown]
# ####Fungsi Recall

# %%
def recall_at_k(I_pred, I_gt, k):
  correct = 0
  for i in range(len(I_pred)):
    correct += len(set(I_pred[i][:k]) & set(I_gt[i][:k]))
  return correct / (len(I_pred) * k)

# %% [markdown]
# ####Benchmark Annoy

# %%
def run_annoy(xb, xq, n_trees=10, search_k=1000, k=10):
  f = xb.shape[1]
  index = AnnoyIndex(f, 'euclidean')
  for i, v in enumerate(xb):
    index.add_item(i, v)
  index.build(n_trees)

  start = time.time()
  I = [index.get_nns_by_vector(v, k, search_k=search_k) for v in xq]
  elapsed = (time.time() - start) * 1000 / len(xq)
  rec = recall_at_k(I, gt_idx, k)
  return rec, elapsed

# %% [markdown]
# ####Benchmark FAISS IVF

# %%
def run_faiss(xb, xq, nlist=100, nprobe=10, k=10):
  quantizer = faiss.IndexFlatL2(d)
  index = faiss.IndexIVFFlat(quantizer, d, nlist, faiss.METRIC_L2)
  index.train(xb)
  index.add(xb)

  index.nprobe = nprobe
  strart = time.time()
  _, I = index.search(xq, k)
  elapsed = (time.time() - start) * 1000 / len(xq)
  rec = recall_at_k(I, gt_idx, k)
  return rec, elapsed

# %% [markdown]
# ####Benchmark HNSW

# %%
def run_hnsw(xb, xq, ef=100, M=16, k=10):
  num_elements = xb.shape[0]
  p = hnswlib.Index(space='l2', dim=d)
  p.init_index(max_elements=num_elements, ef_construction=200, M=M)
  p.add_items(xb)
  p.set_ef(ef)

  start = time.time()
  I, _ = p.knn_query(xq, k)
  elapsed = (time.time() - start) * 1000 / len(xq)
  rec = recall_at_k(I, gt_idx, k)
  return rec, elapsed

# %% [markdown]
# ####Menjalankan benchmark dengan parameter

# %%
results = {"Annoy": [], "Faiss": [], "HNSW": []}

# Annoy
for sk in [200, 500, 1000, 2000]:
  rec, t = run_annoy(xb, xq, n_trees=10, search_k=sk)
  results["Annoy"].append((rec, t))

# FAISS
for npb in [1, 5, 10, 20]:
  rec, t = run_faiss(xb, xq, nlist=100, nprobe=npb)
  results["Faiss"].append((rec, t))

# HNSW
for ef in [50, 100, 200, 400]:
  rec, t = run_hnsw(xb, xq, ef=ef, k=k)
  results["HNSW"].append((rec, t))

# %% [markdown]
# ####Visualisasi Trade-off

# %%
plt.figure(figsize=(8,6))
for label, color in zip(results.keys(), ["blue","green","red"]):
    recall, qtime = zip(*results[label])
    plt.plot(recall, qtime, marker="o", label=label, color=color)

plt.xlabel("Recall")
plt.ylabel("Query Time (ms/query, log scale)")
plt.yscale("log")
plt.gca().invert_yaxis()  # invert Y, makin kanan makin turun
plt.title("ANN Benchmark (Annoy vs Faiss vs HNSW)")
plt.legend()
plt.grid(True, which="both", ls="--", alpha=0.6)
plt.show()
