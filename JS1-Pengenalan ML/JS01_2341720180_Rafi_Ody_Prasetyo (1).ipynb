# %% [markdown]
# #BAGIAN 1

# %% [markdown]
# ##pyPREP
# Library PyPREP adalah implementasi Python dari PREP pipeline (EEG Preprocessing Pipeline) yang awalnya dikembangkan dalam MATLAB.
# Kegunaan:
# - Meningkatkan Kualitas Data EEG
# - Referencing EEG (Robust Re-referencing)
# - Pipeline yang Reproducible

# %%
# !pip install --upgrade pyprep

# %%
import mne
from pyprep.prep_pipeline import PrepPipeline

# %% [markdown]
# ##SciPy
#
# SciPy adalah salah satu library Python yang digunakan untuk ilmu data, analisis statistik, dan perhitungan ilmiah. SciPy berguna untuk analisis statistik, optimisasi, integrasi, interpolasi, dan masalah matematika lainnya.

# %%
# !pip install scipy

# %%
import scipy
print(scipy.__version__)
# Out:
# 1.16.1

# %% [markdown]
# ##Wandb
# Weight & Biases (W&B) merupakan library yang berfungsi untuk melacak (tracking) dan memvisualisasikan eksperimen machine learning.

# %%
# !pip install wandb

# %%
import wandb
wandb.login()
# Out:
# True

# %% [markdown]
# ##pyECG
# pyECG adalah library yang digunakan untuk pembacaan/penulisan format dataset ECG.

# %%
# !pip install pyECG --no-deps
# !pip install numpy wfdb ishneholterlib
# !pip install pythoncrc

# %%
from pyecg import ECGRecord

# %% [markdown]
# #BAGIAN 2

# %% [markdown]
# ##1. Berikan contoh tentang tidakan melanggar etika dan hukum tentang penggunaan kecerdasan buatan. Sertakan referensi yang digunakan.
#
# Jawab: Penyalahgunaan video AI VEO3 untuk menyebarkan konten rasisme menunjukkan bahwa teknologi generative AI dapat digunakan untuk tujuan berbahaya. Selain itu, pelacakan terhadap pihak yang membuat prompt sering kali sulit dilakukan, sehingga pelaku sulit diidentifikasi.
#
# Referensi: https://tekno.kompas.com/read/2025/07/06/09090057/tiktok-diserbu-video-ai-rasis-diduga-pakai-google-veo-3?page=all

# %% [markdown]
# ##2. Berikan contoh tentang dampak energi dan lingkungan terhadap pemanfaatan kecerdasan buatan dan bagaimana cara mengatasinya (Anda dapat memberikan pendapat pribadi). Sertakan referensi yang digunakan.
#
# Jawab: Penggunaan air mineral secara berlebihan untuk pendingin dan pembangkit listrik server AI. Jika hal ini terus menerus terjadi, maka kebutuhan air mineral untuk kelangsungan hidup akan semakin berkurang. Terdapat solusi yang dapat dilakukan yaitu dengan menggunakan greywater (air daur ulang). Namun greywater harus diolah menjadi air bersih terlebih dahulu agar dapat digunakan.
#
# Referensi:
# https://www.bbc.com/indonesia/articles/c20n2q29lz3o
# https://repository.ub.ac.id/id/eprint/11405/
