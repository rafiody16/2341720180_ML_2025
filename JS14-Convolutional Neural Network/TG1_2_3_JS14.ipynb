# %% [markdown]
# ##Tugas JS 14

# %% [markdown]
# ###Modifikasi model CNN pada praktikum 2 sehingga didapatkan akurasi testing lebih dari 80%.

# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models, regularizers
import matplotlib.pyplot as plt

(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()

train_images, test_images = train_images / 255.0, test_images / 255.0
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 325s 2us/step

# %%
model = models.Sequential()

# %%
model.add(layers.RandomFlip("horizontal", input_shape=(32, 32, 3)))
model.add(layers.RandomRotation(0.1))
model.add(layers.RandomZoom(0.1))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/preprocessing/tf_data_layer.py:19: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.add(layers.Conv2D(32, (3, 3), padding='same', activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(32, (3, 3), padding='same', activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.2))

# %%
model.add(layers.Conv2D(64, (3, 3), padding='same', activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(64, (3, 3), padding='same', activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.3))

# %%
model.add(layers.Conv2D(128, (3, 3), padding='same', activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(128, (3, 3), padding='same', activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.4))

# %%
model.add(layers.Flatten())
model.add(layers.Dense(128, activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(10))

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ random_flip (RandomFlip)        │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_rotation                 │ (None, 32, 32, 3)      │             0 │
# │ (RandomRotation)                │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_zoom (RandomZoom)        │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 32, 32, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 16, 16, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 8, 8, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 8, 8, 128)      │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 552,874 (2.11 MB)
#  Trainable params: 551,722 (2.10 MB)
#  Non-trainable params: 1,152 (4.50 KB)

# %%
model.compile(optimizer='adam', loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(
    monitor = 'val_accuracy',
    factor = 0.5,
    patience = 3,
    min_lr = 0.00001
)

# %%
history = model.fit(train_images, train_labels,
                    epochs=40,
                    validation_data=(test_images, test_labels),
                    callbacks=[lr_scheduler])
# Out:
# Epoch 1/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 480s 302ms/step - accuracy: 0.3164 - loss: 2.1175 - val_accuracy: 0.4550 - val_loss: 1.5102 - learning_rate: 0.0010
# Epoch 2/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 479s 306ms/step - accuracy: 0.5130 - loss: 1.3675 - val_accuracy: 0.5850 - val_loss: 1.1995 - learning_rate: 0.0010
# Epoch 3/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 479s 306ms/step - accuracy: 0.5748 - loss: 1.2039 - val_accuracy: 0.6301 - val_loss: 1.0706 - learning_rate: 0.0010
# Epoch 4/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 498s 304ms/step - accuracy: 0.6233 - loss: 1.0864 - val_accuracy: 0.6721 - val_loss: 0.9250 - learning_rate: 0.0010
# Epoch 5/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 474s 303ms/step - accuracy: 0.6475 - loss: 1.0171 - val_accuracy: 0.7074 - val_loss: 0.8640 - learning_rate: 0.0010
# Epoch 6/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 499s 301ms/step - accuracy: 0.6613 - loss: 0.9720 - val_accuracy: 0.6944 - val_loss: 0.8906 - learning_rate: 0.0010
# Epoch 7/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 514s 309ms/step - accuracy: 0.6821 - loss: 0.9245 - val_accuracy: 0.7370 - val_loss: 0.7588 - learning_rate: 0.0010
# Epoch 8/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 514s 329ms/step - accuracy: 0.6992 - loss: 0.8837 - val_accuracy: 0.7317 - val_loss: 0.7804 - learning_rate: 0.0010
# Epoch 9/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 501s 321ms/step - accuracy: 0.7079 - loss: 0.8425 - val_accuracy: 0.7137 - val_loss: 0.8470 - learning_rate: 0.0010
# Epoch 10/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 488s 312ms/step - accuracy: 0.7191 - loss: 0.8213 - val_accuracy: 0.7218 - val_loss: 0.8364 - learning_rate: 0.0010
# Epoch 11/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 499s 310ms/step - accuracy: 0.7362 - loss: 0.7714 - val_accuracy: 0.7850 - val_loss: 0.6315 - learning_rate: 5.0000e-04
# Epoch 12/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 521s 322ms/step - accuracy: 0.7491 - loss: 0.7368 - val_accuracy: 0.7891 - val_loss: 0.6221 - learning_rate: 5.0000e-04
# Epoch 13/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 483s 309ms/step - accuracy: 0.7514 - loss: 0.7317 - val_accuracy: 0.7810 - val_loss: 0.6484 - learning_rate: 5.0000e-04
# Epoch 14/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 497s 318ms/step - accuracy: 0.7606 - loss: 0.7062 - val_accuracy: 0.7848 - val_loss: 0.6487 - learning_rate: 5.0000e-04
# Epoch 15/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 517s 331ms/step - accuracy: 0.7595 - loss: 0.6982 - val_accuracy: 0.8019 - val_loss: 0.5851 - learning_rate: 5.0000e-04
# Epoch 16/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 540s 317ms/step - accuracy: 0.7639 - loss: 0.6968 - val_accuracy: 0.8072 - val_loss: 0.5681 - learning_rate: 5.0000e-04
# Epoch 17/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 496s 317ms/step - accuracy: 0.7635 - loss: 0.6943 - val_accuracy: 0.7899 - val_loss: 0.6298 - learning_rate: 5.0000e-04
# Epoch 18/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 489s 313ms/step - accuracy: 0.7729 - loss: 0.6750 - val_accuracy: 0.8114 - val_loss: 0.5650 - learning_rate: 5.0000e-04
# Epoch 19/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 497s 318ms/step - accuracy: 0.7743 - loss: 0.6623 - val_accuracy: 0.8077 - val_loss: 0.5716 - learning_rate: 5.0000e-04
# Epoch 20/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 519s 332ms/step - accuracy: 0.7781 - loss: 0.6584 - val_accuracy: 0.8167 - val_loss: 0.5425 - learning_rate: 5.0000e-04
# Epoch 21/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 511s 327ms/step - accuracy: 0.7779 - loss: 0.6519 - val_accuracy: 0.8124 - val_loss: 0.5576 - learning_rate: 5.0000e-04
# Epoch 22/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 485s 310ms/step - accuracy: 0.7818 - loss: 0.6571 - val_accuracy: 0.8050 - val_loss: 0.5775 - learning_rate: 5.0000e-04
# Epoch 23/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 501s 320ms/step - accuracy: 0.7806 - loss: 0.6542 - val_accuracy: 0.8103 - val_loss: 0.5681 - learning_rate: 5.0000e-04
# Epoch 24/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 502s 320ms/step - accuracy: 0.7862 - loss: 0.6325 - val_accuracy: 0.8266 - val_loss: 0.5170 - learning_rate: 2.5000e-04
# Epoch 25/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 497s 317ms/step - accuracy: 0.7974 - loss: 0.6048 - val_accuracy: 0.8222 - val_loss: 0.5354 - learning_rate: 2.5000e-04
# Epoch 26/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 495s 317ms/step - accuracy: 0.7948 - loss: 0.5996 - val_accuracy: 0.8182 - val_loss: 0.5415 - learning_rate: 2.5000e-04
# Epoch 27/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 505s 319ms/step - accuracy: 0.7959 - loss: 0.5975 - val_accuracy: 0.8317 - val_loss: 0.4973 - learning_rate: 2.5000e-04
# Epoch 28/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 493s 315ms/step - accuracy: 0.7993 - loss: 0.5950 - val_accuracy: 0.8278 - val_loss: 0.5099 - learning_rate: 2.5000e-04
# Epoch 29/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 519s 332ms/step - accuracy: 0.7984 - loss: 0.5972 - val_accuracy: 0.8160 - val_loss: 0.5327 - learning_rate: 2.5000e-04
# Epoch 30/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 492s 315ms/step - accuracy: 0.7999 - loss: 0.5918 - val_accuracy: 0.8318 - val_loss: 0.4939 - learning_rate: 2.5000e-04
# Epoch 31/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 495s 316ms/step - accuracy: 0.8023 - loss: 0.5787 - val_accuracy: 0.8338 - val_loss: 0.4896 - learning_rate: 1.2500e-04
# Epoch 32/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 495s 312ms/step - accuracy: 0.8078 - loss: 0.5631 - val_accuracy: 0.8331 - val_loss: 0.4964 - learning_rate: 1.2500e-04
# Epoch 33/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 510s 317ms/step - accuracy: 0.8071 - loss: 0.5694 - val_accuracy: 0.8446 - val_loss: 0.4653 - learning_rate: 1.2500e-04
# Epoch 34/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 498s 314ms/step - accuracy: 0.8108 - loss: 0.5617 - val_accuracy: 0.8354 - val_loss: 0.4893 - learning_rate: 1.2500e-04
# Epoch 35/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 502s 314ms/step - accuracy: 0.8085 - loss: 0.5605 - val_accuracy: 0.8360 - val_loss: 0.4878 - learning_rate: 1.2500e-04
# Epoch 36/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 489s 313ms/step - accuracy: 0.8057 - loss: 0.5715 - val_accuracy: 0.8398 - val_loss: 0.4741 - learning_rate: 1.2500e-04
# Epoch 37/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 511s 318ms/step - accuracy: 0.8117 - loss: 0.5527 - val_accuracy: 0.8459 - val_loss: 0.4636 - learning_rate: 6.2500e-05
# Epoch 38/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 514s 329ms/step - accuracy: 0.8113 - loss: 0.5540 - val_accuracy: 0.8414 - val_loss: 0.4661 - learning_rate: 6.2500e-05
# Epoch 39/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 487s 312ms/step - accuracy: 0.8137 - loss: 0.5488 - val_accuracy: 0.8439 - val_loss: 0.4606 - learning_rate: 6.2500e-05
# Epoch 40/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 500s 320ms/step - accuracy: 0.8146 - loss: 0.5475 - val_accuracy: 0.8413 - val_loss: 0.4709 - learning_rate: 6.2500e-05

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

test_loss, test_acc = model.evaluate(test_images, test_labels, verbose=2)
# Out:
# 313/313 - 20s - 64ms/step - accuracy: 0.8413 - loss: 0.4709

# %%
model.save('/content/drive/My Drive/cifar10_tugas.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ###Buatlah model CNN untuk klasifikasi dataset MNIST.

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
import numpy as np

(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

x_train, x_test = x_train / 255.0, x_test / 255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
x_train = x_train.reshape((-1, 28, 28, 1))
x_test = x_test.reshape((-1, 28, 28, 1))

# %%
model = models.Sequential()

# %% [markdown]
# Layer Konvolusi 1

# %%
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))
model.add(layers.MaxPooling2D((2, 2)))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# Layer Konvolusi 2

# %%
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))

# %% [markdown]
# Layer Konvolusi 3

# %%
model.add(layers.Conv2D(64, (3, 3), activation='relu'))

# %% [markdown]
# Mengubah data 2D menjadi vektor 1D

# %%
model.add(layers.Flatten())

# %% [markdown]
# Layer Klasifikasi

# %%
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))

# %% [markdown]
# Compile model

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# Struktur

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 11, 11, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 3, 3, 64)       │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 576)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 93,322 (364.54 KB)
#  Trainable params: 93,322 (364.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Melatih model

# %%
history = model.fit(x_train, y_train, epochs=10, validation_data=(x_test, y_test))
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 52s 27ms/step - accuracy: 0.8951 - loss: 0.3391 - val_accuracy: 0.9850 - val_loss: 0.0499
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 48s 26ms/step - accuracy: 0.9841 - loss: 0.0506 - val_accuracy: 0.9881 - val_loss: 0.0395
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 86s 28ms/step - accuracy: 0.9901 - loss: 0.0344 - val_accuracy: 0.9857 - val_loss: 0.0468
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 50s 27ms/step - accuracy: 0.9913 - loss: 0.0264 - val_accuracy: 0.9896 - val_loss: 0.0339
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 83s 27ms/step - accuracy: 0.9940 - loss: 0.0179 - val_accuracy: 0.9923 - val_loss: 0.0254
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 49s 26ms/step - accuracy: 0.9957 - loss: 0.0137 - val_accuracy: 0.9915 - val_loss: 0.0276
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - accuracy: 0.9965 - loss: 0.0111 - val_accuracy: 0.9918 - val_loss: 0.0280
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 50s 27ms/step - accuracy: 0.9968 - loss: 0.0104 - val_accuracy: 0.9915 - val_loss: 0.0309
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 49s 26ms/step - accuracy: 0.9980 - loss: 0.0072 - val_accuracy: 0.9929 - val_loss: 0.0278
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 52s 28ms/step - accuracy: 0.9976 - loss: 0.0070 - val_accuracy: 0.9933 - val_loss: 0.0287

# %%
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)
print(f"\nAkurasi pada data test: {test_acc*100:.2f}%")
# Out:
# 313/313 - 2s - 7ms/step - accuracy: 0.9933 - loss: 0.0287
#
# Akurasi pada data test: 99.33%

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')
plt.show()
